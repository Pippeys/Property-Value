# %%
#Scraping contact info from Santa Cruz realty
import bs4 as bs
import urllib.request
import csv
import lxml

sauce = urllib.request.urlopen('file:///C:/Users/sstandring/Downloads/reach2016.html')
soup = bs.BeautifulSoup(sauce, 'lxml')
data = soup.find_all('p',style = "padding-left: 5pt;text-indent: 0pt;text-align: left;" )

for p in data:
    stuff = p.text
    print(stuff)
# Out:
# Bailey Properties, Inc. 1602 Ocean Street Santa Cruz, CA 95060
# F: 831-426-7830
# cabramson@baileyproperties.com
# Helen G. Ackerman
# Real Estate Eight Three One 4510 Capitola Road
# O: 831-475-5695, M: 831-332-5299
# F: 831-475-5693
# ninitoo@comcast.net
# Jeffrey G. Acton
# Acton Real Estate Services 932 Kings Canyon Ct Scotts Valley, CA 95066
# F: 831-336-3624
# jacton1@prodigy.net
# Schatzi Adams American Dream Realty 6287 Highway 9
# O: 831-335-5700, M: 831-419-3449
# F: 831-335-4763
# realeschatzi@yahoo.com
# Lori Adragna Keller Williams 262 E. Main Street
# O: 408-356-8009, M: 831-239-2004
# lorikwrealtor@gmail.com
# Miguel Aguilera Alliance Bay Realty
# Newark, CA 94560
# O: 510-742-6600, M: 831-421-1400
# miguelhaguilera@gmail.com
# Kem J. Akol
# Bailey Properties, Inc. 9119 Soquel Drive
# O: 831-688-7434, M: 831-247-2944
# F: 831-685-6422
# kemakol@msn.com
# Robert Aldana American Dream Realty 5522 Scotts Valley Dr Scotts Valley, CA 95066
# F: 831-438-0724
# ...
